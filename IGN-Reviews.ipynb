# %%
# %matplotlib inline
import numpy as np
import pandas as pd

df = pd.read_csv("ign.csv")
df[df["platform"] == "iPhone"]["score"].plot(kind="hist")

# %%
df.shape
# Out:
# (18625, 11)

# %%
df.iloc[:,1:]
# Out:
#       score_phrase                                              title  \
# 0          Amazing                            LittleBigPlanet PS Vita
# 1          Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2            Great                               Splice: Tree of Life
# 3            Great                                             NHL 13
# 4            Great                                             NHL 13
# 5             Good                          Total War Battles: Shogun
# 6            Awful                                Double Dragon: Neon
# 7          Amazing                                       Guild Wars 2
# 8            Awful                                Double Dragon: Neon
# 9             Good                          Total War Battles: Shogun
# 10            Good                            Tekken Tag Tournament 2
# 11            Good                            Tekken Tag Tournament 2
# ...

# %%
smalldf=df.iloc[10:20,]
smalldf
# Out:
#     sno score_phrase                            title  \
# 10   10         Good          Tekken Tag Tournament 2
# 11   11         Good          Tekken Tag Tournament 2
# 12   12         Good                       Wild Blood
# 13   13      Amazing                Mark of the Ninja
# 14   14      Amazing                Mark of the Ninja
# 15   15         Okay  Home: A Unique Horror Adventure
# 16   16         Okay  Home: A Unique Horror Adventure
# 17   17        Great              Avengers Initiative
# 18   18     Mediocre             Way of the Samurai 4
# 19   19         Good      JoJo's Bizarre Adventure HD
#
#                                                   url       platform  score  \
# 10          /games/tekken-tag-tournament-2/ps3-124584  PlayStation 3    7.5
# 11     /games/tekken-tag-tournament-2/xbox-360-124581       Xbox 360    7.5
# 12                    /games/wild-blood/iphone-139363         iPhone    7.0
# ...

# %%
smalldf.loc[0:20,["genre","title"]]
# Out:
#                 genre                            title
# 10           Fighting          Tekken Tag Tournament 2
# 11           Fighting          Tekken Tag Tournament 2
# 12                NaN                       Wild Blood
# 13  Action, Adventure                Mark of the Ninja
# 14  Action, Adventure                Mark of the Ninja
# 15          Adventure  Home: A Unique Horror Adventure
# 16          Adventure  Home: A Unique Horror Adventure
# 17             Action              Avengers Initiative
# 18  Action, Adventure             Way of the Samurai 4
# 19           Fighting      JoJo's Bizarre Adventure HD

# %%
smalldf.loc[:,["genre","title"]]
# Out:
#                 genre                            title
# 10           Fighting          Tekken Tag Tournament 2
# 11           Fighting          Tekken Tag Tournament 2
# 12                NaN                       Wild Blood
# 13  Action, Adventure                Mark of the Ninja
# 14  Action, Adventure                Mark of the Ninja
# 15          Adventure  Home: A Unique Horror Adventure
# 16          Adventure  Home: A Unique Horror Adventure
# 17             Action              Avengers Initiative
# 18  Action, Adventure             Way of the Samurai 4
# 19           Fighting      JoJo's Bizarre Adventure HD

# %%
type(smalldf["genre"])
# Out:
# pandas.core.series.Series

# %%
smalldf.head()
# Out:
#     sno score_phrase                    title  \
# 10   10         Good  Tekken Tag Tournament 2
# 11   11         Good  Tekken Tag Tournament 2
# 12   12         Good               Wild Blood
# 13   13      Amazing        Mark of the Ninja
# 14   14      Amazing        Mark of the Ninja
#
#                                                 url       platform  score  \
# 10        /games/tekken-tag-tournament-2/ps3-124584  PlayStation 3    7.5
# 11   /games/tekken-tag-tournament-2/xbox-360-124581       Xbox 360    7.5
# 12                  /games/wild-blood/iphone-139363         iPhone    7.0
# 13  /games/mark-of-the-ninja-135615/xbox-360-129276       Xbox 360    9.0
# 14        /games/mark-of-the-ninja-135615/pc-143761             PC    9.0
#
#                 genre editors_choice  release_year  release_month  release_day
# 10           Fighting              N          2012              9           11
# 11           Fighting              N          2012              9           11
# ...

# %%
df["score"].mean()
# Out:
# 6.950459060402685

# %%
df.mean()
# Out:
# sno              9312.000000
# score               6.950459
# release_year     2006.515329
# release_month       7.138470
# release_day        15.603866
# dtype: float64

# %%
df.iloc[:,1:].corr()
# Out:
#                   score  release_year  release_month  release_day
# score          1.000000      0.062716       0.007632     0.020079
# release_year   0.062716      1.000000      -0.115515     0.016867
# release_month  0.007632     -0.115515       1.000000    -0.067964
# release_day    0.020079      0.016867      -0.067964     1.000000

# %%
df["score"]/2
# Out:
# 0        4.50
# 1        4.50
# 2        4.25
# 3        4.25
# 4        4.25
# 5        3.50
# 6        1.50
# 7        4.50
# 8        1.50
# 9        3.50
# 10       3.75
# 11       3.75
# 12       3.50
# 13       4.50
# 14       4.50
# 15       3.25
# 16       3.25
# 17       4.00
# 18       2.75
# 19       3.50
# 20       3.50
# 21       3.75
# 22       3.75
# 23       3.75
# 24       4.50
# 25       3.50
# 26       4.50
# 27       3.75
# 28       4.00
# 29       3.25
#          ...
# 18595    2.20
# 18596    3.25
# 18597    2.45
# 18598    3.40
# 18599    3.50
# 18600    3.70
# 18601    3.70
# 18602    3.70
# 18603    3.90
# 18604    4.30
# 18605    3.00
# 18606    3.20
# 18607    3.50
# 18608    2.70
# 18609    4.00
# 18610    3.00
# 18611    2.90
# 18612    3.90
# 18613    4.00
# 18614    4.60
# 18615    4.60
# 18616    3.75
# 18617    4.20
# 18618    4.55
# 18619    3.95
# 18620    3.80
# 18621    4.50
# 18622    2.90
# 18623    5.00
# 18624    5.00
# ...

# %%
scorefilter=df["score"]>9

# %%
scorefilter
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 18595    False
# 18596    False
# 18597    False
# 18598    False
# 18599    False
# 18600    False
# 18601    False
# 18602    False
# 18603    False
# 18604    False
# 18605    False
# 18606    False
# 18607    False
# 18608    False
# 18609    False
# 18610    False
# 18611    False
# 18612    False
# 18613    False
# 18614     True
# 18615     True
# 18616    False
# 18617    False
# 18618     True
# 18619    False
# 18620    False
# 18621    False
# ...

# %%
filteredreviews=df[scorefilter]

# %%
filteredreviews.head(14)
# Out:
#      sno score_phrase                                title  \
# 33    33      Amazing              Pokemon White Version 2
# 35    35      Amazing              Pokemon Black Version 2
# 45    45      Amazing                          Bad Piggies
# 50    50      Amazing                             NBA 2K13
# 52    52      Amazing  The World Ends with You: Solo Remix
# 54    54      Amazing  The World Ends with You: Solo Remix
# 60    60      Amazing                             NBA 2K13
# 61    61      Amazing                             NBA 2K13
# 98    98      Amazing                          Punch Quest
# 110  110      Amazing                        Torchlight II
# 135  135      Amazing    Zero Escape: Virtue's Last Reward
# 136  136      Amazing    Zero Escape: Virtue's Last Reward
# 166  166      Amazing                           Dishonored
# 167  167      Amazing                           Dishonored
#
#                                                    url          platform  \
# ...

# %%
df["score"].count()
# Out:
# 18625

# %%
filteredreviews= (df["score"]>8) & (df["editors_choice"]=="Y")

# %%
new=df[filteredreviews]

# %%
new.count()
# Out:
# sno               3343
# score_phrase      3343
# title             3343
# url               3343
# platform          3343
# score             3343
# genre             3342
# editors_choice    3343
# release_year      3343
# release_month     3343
# release_day       3343
# dtype: int64

# %%
new.head(30)
# Out:
#     sno score_phrase                                              title  \
# 0     0      Amazing                            LittleBigPlanet PS Vita
# 1     1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 7     7      Amazing                                       Guild Wars 2
# 13   13      Amazing                                  Mark of the Ninja
# 14   14      Amazing                                  Mark of the Ninja
# 24   24      Amazing                Dark Souls (Prepare to Die Edition)
# 26   26      Amazing                                            Bastion
# 30   30      Amazing  The Walking Dead: The Game -- Episode 3: Long ...
# 31   31        Great               World of Warcraft: Mists of Pandaria
# 33   33      Amazing                            Pokemon White Version 2
# 35   35      Amazing                            Pokemon Black Version 2
# 37   37      Amazing  The Walking Dead: The Game -- Episode 3: Long ...
# ...

# %%
filterplotgraph=df["platform"]=="iPhone"

# %%
plotiPhone=df[filterplotgraph]
plotiPhone
# Out:
#          sno score_phrase                                              title  \
# 12        12         Good                                         Wild Blood
# 17        17        Great                                Avengers Initiative
# 36        36         Okay                                         Drakerider
# 45        45      Amazing                                        Bad Piggies
# 49        49         Okay                                      Demon's Score
# 54        54      Amazing                The World Ends with You: Solo Remix
# 62        62         Good                                Lili: Child of Geos
# 76        76      Amazing                                       Hero Academy
# 77        77      Amazing                                       Puzzle Craft
# 86        86      Amazing                                               Horn
# 90        90         Good                                         Crazy Taxi
# ...

# %%
df[df["platform"] == "iPhone"]["score"].plot(kind="hist")

# %%
df[df["platform"]=="Xbox One"]["score"].plot(kind="hist")

# %%
import matplotlib.pyplot as plt
